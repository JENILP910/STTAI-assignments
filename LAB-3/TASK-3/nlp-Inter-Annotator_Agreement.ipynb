# %%
# %pip install scikit-learn
# %pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path

current_dir = Path.cwd().parent
print("Current directory:", current_dir)

datasetDir = current_dir / "Task-2"
print("Subfolder path:", datasetDir)
# Out:
# Current directory: c:\Users\JENIL\Desktop\LABS SEM-2\Software Tools & Techniques for AI\LabWork\LAB-3
# Subfolder path: c:\Users\JENIL\Desktop\LABS SEM-2\Software Tools & Techniques for AI\LabWork\LAB-3\Task-2

# %%
type(datasetDir)
# Out:
# pathlib.WindowsPath

# %% [markdown]
# # 1.Cohen’s Kappa for the NLP Dataset Task

# %%
def create_sentence_labels(data):
    sentences_data = {}

    for entry in data:
        sentence_text = entry["data"]["text"]
        # print(sentence_text)
        annotations = entry["annotations"][0]["result"]  # Assuming 1 annotation per sentence
        # print(annotations)
        
        # Extract tokens for annotator 1
        word_labels = {
            # {"text": ann["value"]["text"], "label": ann["value"]["labels"][0]}
            ann["value"]["text"] : ann["value"]["labels"][0]
            for ann in annotations
        }

        sentences_data[sentence_text] = word_labels
    return sentences_data

# %%
import json

# Load the data
with open(datasetDir.__str__()+"\JENIL_POS.json", "r", encoding="utf-8") as f:
    data = json.load(f)

dataset1 = create_sentence_labels(data)

# Load the second data
with open(datasetDir.__str__()+"\Mithlesh_POS.json", "r", encoding="utf-8") as f:
    data = json.load(f)

dataset2 = create_sentence_labels(data)

# %%
# printing data
for sentence, word_labels in dataset1.items():
    print(sentence)
    print(word_labels)
    break
# Out:
# गृह लक्ष्मी योजना की शुरुआत के मौके पर PM Modi-Amit Shah को Mallikarjun Kharge का करारा जवाब।
# {'गृह ': 'NOUN', 'लक्ष्मी ': 'NOUN', 'योजना ': 'NOUN', 'की ': 'ADP', 'शुरुआत': 'NOUN', 'के': 'ADP', 'मौके': 'NOUN', 'पर': 'ADP', 'PM': 'PROPN', 'Modi': 'PROPN', 'Amit': 'PROPN', 'Shah': 'PROPN', 'को': 'ADP', 'Mallikarjun': 'PROPN', 'Kharge': 'PROPN', 'का': 'ADP', 'करारा ': 'ADJ', 'जवाब': 'NOUN'}

# %%
# For observed_agreement

for (sentence_1, word_labels_1), (sentence_2, word_labels_2) in zip(dataset1.items(), dataset2.items()):
    print(f"Word 1: {sentence_1}, Labels 1: {word_labels_1}")
    print(f"Word 2: {sentence_2}, Labels 2: {word_labels_2}")
    break
# Out:
# Word 1: गृह लक्ष्मी योजना की शुरुआत के मौके पर PM Modi-Amit Shah को Mallikarjun Kharge का करारा जवाब।, Labels 1: {'गृह ': 'NOUN', 'लक्ष्मी ': 'NOUN', 'योजना ': 'NOUN', 'की ': 'ADP', 'शुरुआत': 'NOUN', 'के': 'ADP', 'मौके': 'NOUN', 'पर': 'ADP', 'PM': 'PROPN', 'Modi': 'PROPN', 'Amit': 'PROPN', 'Shah': 'PROPN', 'को': 'ADP', 'Mallikarjun': 'PROPN', 'Kharge': 'PROPN', 'का': 'ADP', 'करारा ': 'ADJ', 'जवाब': 'NOUN'}
# Word 2: गृह लक्ष्मी योजना की शुरुआत के मौके पर PM Modi-Amit Shah को Mallikarjun Kharge का करारा जवाब।, Labels 2: {'गृह': 'NOUN', 'लक्ष्मी ': 'NOUN', 'योजना ': 'NOUN', 'की ': 'ADP', 'शुरुआत ': 'VERB', 'के ': 'ADP', 'मौके': 'NOUN', 'पर ': 'ADP', 'PM ': 'PROPN', 'Modi': 'PROPN', 'Amit ': 'PROPN', 'Shah ': 'PROPN', ' ': 'ADP', 'को ': 'ADP', 'Mallikarjun': 'PROPN', 'Kharge ': 'PROPN', 'का ': 'ADP', 'करारा ': 'ADJ', 'जवाब': 'NOUN'}

# %%
# For observed agreement
observed_agreement = {}

for (sentence_1, word_labels_1), (sentence_2, word_labels_2) in zip(dataset1.items(), dataset2.items()):
    # print(f"Word 1: {sentence_1}, Labels 1: {word_labels_1}")
    # print(f"Word 2: {sentence_2}, Labels 2: {word_labels_2}")
    if (sentence_1 == sentence_2):
        # Clean the words by stripping any leading/trailing spaces before getting the keys
        word_labels_1 = {k.strip(): v for k, v in word_labels_1.items()}
        word_labels_2 = {k.strip(): v for k, v in word_labels_2.items()}

        # Inner join: Get common words between annotators and compare labels
        common_word_labels = set(word_labels_1.keys()) & (set(word_labels_2.keys()))

        joined_data = {}
        for word in common_word_labels:
            labels_1 = word_labels_1[word]
            labels_2 = word_labels_2[word]
            
            # Checking if the labels are the same
            joined_data[word] = labels_1 == labels_2

        # print(joined_data)
        observed_agreement[sentence_1] = joined_data
    # break

# %%
observed_agreement
# Out:
# {'गृह लक्ष्मी योजना की शुरुआत के मौके पर PM Modi-Amit Shah को Mallikarjun Kharge का करारा जवाब।': {'Kharge': True,
#   'की': True,
#   'लक्ष्मी': True,
#   'योजना': True,
#   'गृह': True,
#   'मौके': True,
#   'जवाब': True,
#   'शुरुआत': False,
#   'Shah': True,
#   'पर': True,
#   'को': True,
#   'Mallikarjun': True,
#   'के': True,
#   'का': True,
#   'PM': True,
#   'Modi': True,
#   'करारा': True,
#   'Amit': True},
#  'दुनिया की सबसे बड़ी महिला डायरेक्ट बेनिफिट ट्रांसफर स्कीम आज से शुरू| Gruha Lakshmi Yojana Karnataka': {'बेनिफिट': False,
#   'दुनिया': True,
#   'की': False,
#   'Lakshmi': True,
#   'स्कीम': False,
#   'सबसे': False,
#   'Yojana': True,
#   'आज': True,
#   'से': True,
#   'शुरू': False,
#   'बड़ी': False,
#   'महिला': True,
#   'Gruha': True,
#   'डायरेक्ट': False,
#   'Karnataka': True,
#   'ट्रांसफर': False},
#  '"महिलाओं को तोहफा, Congress हर महीने 2000 रुपये देगी | Gruha Lakshmi Yojana Karnataka | Rahul Gandhi"': {'2000': True,
#   'Congress': True,
#   'Karnataka': True,
#   'Lakshmi': True,
#   'Rahul': True,
#   'महीने': True,
#   'हर': False,
#   'महिलाओं': True,
#   'देगी': False,
#   'Yojana': True,
#   'Gandhi': True,
#   'रुपये': True,
#   'को': True,
#   'Gruha': True,
#   'तोहफा': True},
#  "ये INDIA की ताकत है कि Modi सरकार Gas Cylinder के दाम घटाने को मजबूर हैं' Supriya Shrinate": {'की': True,
#   'मजबूर': False,
#   'को': False,
#   'Cylinder': True,
#   'घटाने': False,
#   'Gas': True,
#   'कि': True,
#   'है': True,
#   'ये': False,
#   'हैं': False,
#   'Shrinate': True,
#   'ताकत': False,
#   'के': False,
#   'Supriya': True,
#   'दाम': True,
#   'Modi': True,
#   'सरकार': True,
#   'INDIA': True},
#  '"चीन ने मैप जारी कर अरूणाचल-अक्साई चिन को अपना इलाका बताया, China के दुस्साहस पर Modi चुप क्यों हैं?"': {'के': True,
#   'इलाका': False,
#   'बताया': False,
#   'जारी': False,
#   'दुस्साहस': False,
#   'चीन': True,
#   'चिन': True,
#   'अपना': False,
#   'क्यों': False,
#   'पर': False,
#   'को': True,
#   'चुप': False,
#   'कर': False,
#   'China': False,
#   'ने': True,
#   'मैप': False,
#   'Modi': True,
#   'हैं': True},
#  '"लाल डायरी में BJP के मंत्रियों के नाम, देखते हैं Amit Shah क्या खुलासा करते हैं- Pawan Khera"': {'Pawan': True,
#   'मंत्रियों': True,
#   'Khera': True,
#   'नाम': True,
#   'करते': True,
#   'देखते': False,
#   'BJP': True,
#   'लाल': True,
#   'डायरी': True,
#   'हैं': True,
#   'में': True,
#   'Shah': True,
#   'के': True,
#   'क्या': False,
#   'खुलासा': True,
#   'Amit': True},
#  '"4 दिन पहले Modi-Jinping की मुलाकात, अब चीन नक्शे में अरुणाचल, अक्\u200dसाई चिन को अपना इलाका बता रहा है।"': {'इलाका': True,
#   'की': True,
#   'अब': False,
#   'दिन': True,
#   'चीन': True,
#   'चिन': True,
#   'अक्\u200dसाई': True,
#   'बता': True,
#   'है': True,
#   'अपना': False,
#   'अरुणाचल': True,
#   'में': True,
#   'पहले': False,
#   'को': True,
#   'रहा': True,
#   'नक्शे': True,
#   '4': True,
#   'मुलाकात': True},
#  '"PM Modi से मुलाकात के 4 दिन बाद China ने अरुणाचल-अक्साई चिन को अपना इलाका बताया, भड़के Pawan Khera"': {'Pawan': True,
#   'इलाका': True,
#   'Khera': True,
#   'भड़के': True,
#   'बताया': True,
#   'दिन': True,
#   'चिन': True,
#   'ने': False,
#   'अपना': False,
#   'बाद': False,
#   'से': False,
#   'Modi': True,
#   'को': True,
#   'के': True,
#   'China': True,
#   'PM': True,
#   '4': False,
#   'मुलाकात': True},
#  'INDIA के साथ तरक्की के सफर पर चलेगा देश । INDIA Vs NDA | 2024 Election | Opposition Meeting Mumbai': {'के': True,
#   'Meeting': False,
#   'देश': True,
#   'चलेगा': True,
#   'Mumbai': True,
#   'सफर': True,
#   'Election': True,
#   'NDA': True,
#   'पर': True,
#   'Vs': False,
#   'तरक्की': False,
#   '2024': True,
#   'Opposition': True,
#   'INDIA': True,
#   'साथ': False},
#  'Patna और Bengaluru के बाद अब Mumbai में चक दे INDIA 🇮🇳 | Opposition Parties Meeting | Rahul Gandhi': {'और': True,
#   'Mumbai': True,
#   '🇮🇳': True,
#   'अब': False,
#   'Meeting': True,
#   'Parties': True,
#   'Bengaluru': True,
#   'Rahul': True,
#   'चक': True,
#   'बाद': False,
#   'Gandhi': True,
#   'में': False,
#   'के': True,
#   'दे': False,
#   'Opposition': True,
#   'INDIA': True,
#   'Patna': True},
#  "यात्रा' में बेबाक बोले INDIA के लोग। Bharat Jodo Yatra | Rahul Gandhi": {'यात्रा': True,
#   'लोग': True,
#   'Bharat': True,
#   'Yatra': False,
#   'Rahul': True,
#   'Jodo': False,
#   'बोले': True,
#   'में': False,
#   'Gandhi': True,
#   'बेबाक': False,
#   'के': True,
#   'INDIA': True},
#  '"माता-पिता को राहत, कांग्रेस करा रही बेटियों की शादी। Congress | Rajasthan | Chhattisgarh"': {'की': True,
#   'Congress': True,
#   'बेटियों': True,
#   'रही': True,
#   'राहत': True,
#   'करा': True,
#   'को': True,
#   'Rajasthan': True,
#   'शादी': True,
#   'Chhattisgarh': True},
#  'Modi-Adani की दोस्ती के चक्कर में देश बर्बाद हो रहा है... | Rahul Gandhi | Congress | BJP': {'के': True,
#   'चक्कर': True,
#   'की': True,
#   'देश': True,
#   'Congress': True,
#   'Adani': True,
#   'बर्बाद': True,
#   'दोस्ती': False,
#   'BJP': True,
#   'है': True,
#   'Gandhi': True,
#   'में': True,
#   'हो': True,
#   'रहा': True,
#   'Modi': True},
#  '"Mallikarjun Kharge ने कही बड़ी बात, अगर संविधान नहीं होता तो आज मैं... | Telangana | Congress"': {'Kharge': True,
#   'बात': True,
#   'संविधान': True,
#   'Telangana': True,
#   'Congress': True,
#   'अगर': True,
#   'नहीं': True,
#   'तो': True,
#   'होता': True,
#   'आज': False,
#   'कही': True,
#   'Mallikarjun': True,
#   'बड़ी': True,
#   'मैं': False},
#  '"हम 2024 में BJP को हरा देंगे... जुड़ेगा भारत, जीतेगा INDIA | Rahul Gandhi | PM Modi"': {'देंगे': True,
#   'Rahul': True,
#   'BJP': True,
#   'जुड़ेगा': False,
#   'जीतेगा': False,
#   'Gandhi': True,
#   'में': True,
#   'को': True,
#   'भारत': True,
#   '2024': True,
#   'हरा': False,
#   'PM': True,
#   'हम': False,
#   'Modi': True,
#   'INDIA': True},
#  'मोदी सरकार 2-3 अरबपतियों की सरकार है- Rahul Gandhi | PM Modi': {'मोदी': True,
#   'की': True,
#   'Rahul': True,
#   'है': False,
#   'Gandhi': True,
#   'PM': True,
#   'अरबपतियों': False,
#   'Modi': True,
#   'सरकार': True},
#  '"PM Modi के सामने झुकने से Nitin Gadkari का इंकार, 2024 से पहले BJP में बड़ी बगावत।"': {'के': True,
#   'सामने': False,
#   'Gadkari': True,
#   'बड़ी': False,
#   'BJP': True,
#   '2024': True,
#   'बगावत': False,
#   'से': True,
#   'झुकने': True,
#   'पहले': False,
#   'में': True,
#   'Nitin': True,
#   'इंकार': True,
#   'का': False,
#   'PM': True,
#   'Modi': True},
#  '"ये है गुजरात मॉडल की असलियत, अब जनता झांसे में नहीं आएगी मोदी जी... | Gujarat Model | PM Modi"': {'आएगी': True,
#   'जनता': True,
#   'की': True,
#   'अब': False,
#   'मोदी': True,
#   'जी': False,
#   'मॉडल': True,
#   'नहीं': True,
#   'गुजरात': True,
#   'Model': True,
#   'है': True,
#   'ये': False,
#   'झांसे': True,
#   'में': True,
#   'Gujarat': True,
#   'असलियत': True,
#   'PM': True,
#   'Modi': True},
#  'Amit Shah को Mallikarjun Kharge ने दिया झन्नाटेदार जवाब। BJP नेताओं की बोलती बंद। Telangana Election': {'Kharge': True,
#   'Telangana': True,
#   'की': True,
#   'झन्नाटेदार': False,
#   'बोलती': False,
#   'BJP': True,
#   'बंद': False,
#   'Election': False,
#   'दिया': True,
#   'जवाब': True,
#   'Mallikarjun': True,
#   'Shah': True,
#   'को': True,
#   'ने': True,
#   'नेताओं': True,
#   'Amit': True},
#  'तेलंगाना में सरकार बनते ही Congress 12 वादे पूरा करेगी- Mallikarjun Kharge | Telangana Election': {'12': True,
#   'पूरा': False,
#   'ही': False,
#   'Kharge': True,
#   'Congress': True,
#   'Telangana': True,
#   'करेगी': True,
#   'तेलंगाना': True,
#   'Election': False,
#   'में': True,
#   'Mallikarjun': True,
#   'बनते': False,
#   'वादे': True,
#   'सरकार': True}}

# %%
# visualizing output
from tabulate import tabulate

for sentence, word_choice in observed_agreement.items():
    print(f"Sentence: {sentence}")

    # Printing the table
    print(tabulate(list(word_choice.items()), headers=["Words", "Is Same"], tablefmt="grid", colalign=("left", "center")), "\n")
# Out:
# Sentence: गृह लक्ष्मी योजना की शुरुआत के मौके पर PM Modi-Amit Shah को Mallikarjun Kharge का करारा जवाब।
# +-------------+-----------+
# | Words       |  Is Same  |
# +=============+===========+
# | Kharge      |   True    |
# +-------------+-----------+
# | की           |   True    |
# +-------------+-----------+
# | लक्ष्मी        |   True    |
# +-------------+-----------+
# | योजना         |   True    |
# +-------------+-----------+
# | गृह          |   True    |
# +-------------+-----------+
# | मौके          |   True    |
# +-------------+-----------+
# | जवाब         |   True    |
# +-------------+-----------+
# | शुरुआत        |   False   |
# +-------------+-----------+
# | Shah        |   True    |
# +-------------+-----------+
# | पर          |   True    |
# +-------------+-----------+
# | को           |   True    |
# +-------------+-----------+
# | Mallikarjun |   True    |
# +-------------+-----------+
# | के           |   True    |
# +-------------+-----------+
# | का           |   True    |
# +-------------+-----------+
# | PM          |   True    |
# +-------------+-----------+
# | Modi        |   True    |
# +-------------+-----------+
# | करारा         |   True    |
# +-------------+-----------+
# | Amit        |   True    |
# +-------------+-----------+
#
# Sentence: दुनिया की सबसे बड़ी महिला डायरेक्ट बेनिफिट ट्रांसफर स्कीम आज से शुरू| Gruha Lakshmi Yojana Karnataka
# +-----------+-----------+
# | Words     |  Is Same  |
# +===========+===========+
# | बेनिफिट      |   False   |
# +-----------+-----------+
# | दुनिया       |   True    |
# +-----------+-----------+
# | की         |   False   |
# +-----------+-----------+
# | Lakshmi   |   True    |
# +-----------+-----------+
# | स्कीम       |   False   |
# +-----------+-----------+
# | सबसे       |   False   |
# +-----------+-----------+
# | Yojana    |   True    |
# +-----------+-----------+
# | आज        |   True    |
# +-----------+-----------+
# | से         |   True    |
# +-----------+-----------+
# | शुरू        |   False   |
# +-----------+-----------+
# | बड़ी        |   False   |
# +-----------+-----------+
# | महिला       |   True    |
# +-----------+-----------+
# | Gruha     |   True    |
# +-----------+-----------+
# | डायरेक्ट     |   False   |
# +-----------+-----------+
# | Karnataka |   True    |
# +-----------+-----------+
# | ट्रांसफर     |   False   |
# +-----------+-----------+
#
# Sentence: "महिलाओं को तोहफा, Congress हर महीने 2000 रुपये देगी | Gruha Lakshmi Yojana Karnataka | Rahul Gandhi"
# +-----------+-----------+
# | Words     |  Is Same  |
# +===========+===========+
# | 2000      |   True    |
# +-----------+-----------+
# | Congress  |   True    |
# +-----------+-----------+
# | Karnataka |   True    |
# +-----------+-----------+
# | Lakshmi   |   True    |
# +-----------+-----------+
# | Rahul     |   True    |
# +-----------+-----------+
# | महीने       |   True    |
# +-----------+-----------+
# | हर        |   False   |
# +-----------+-----------+
# | महिलाओं      |   True    |
# +-----------+-----------+
# | देगी        |   False   |
# +-----------+-----------+
# | Yojana    |   True    |
# +-----------+-----------+
# | Gandhi    |   True    |
# +-----------+-----------+
# | रुपये       |   True    |
# +-----------+-----------+
# | को         |   True    |
# +-----------+-----------+
# | Gruha     |   True    |
# +-----------+-----------+
# | तोहफा       |   True    |
# +-----------+-----------+
#
# Sentence: ये INDIA की ताकत है कि Modi सरकार Gas Cylinder के दाम घटाने को मजबूर हैं' Supriya Shrinate
# +----------+-----------+
# | Words    |  Is Same  |
# +==========+===========+
# | की        |   True    |
# +----------+-----------+
# | मजबूर     |   False   |
# +----------+-----------+
# | को        |   False   |
# +----------+-----------+
# | Cylinder |   True    |
# +----------+-----------+
# | घटाने      |   False   |
# +----------+-----------+
# | Gas      |   True    |
# +----------+-----------+
# | कि        |   True    |
# +----------+-----------+
# | है        |   True    |
# +----------+-----------+
# | ये        |   False   |
# +----------+-----------+
# | हैं        |   False   |
# +----------+-----------+
# | Shrinate |   True    |
# +----------+-----------+
# | ताकत      |   False   |
# +----------+-----------+
# | के        |   False   |
# +----------+-----------+
# | Supriya  |   True    |
# +----------+-----------+
# | दाम       |   True    |
# +----------+-----------+
# | Modi     |   True    |
# +----------+-----------+
# | सरकार     |   True    |
# +----------+-----------+
# | INDIA    |   True    |
# +----------+-----------+
#
# Sentence: "चीन ने मैप जारी कर अरूणाचल-अक्साई चिन को अपना इलाका बताया, China के दुस्साहस पर Modi चुप क्यों हैं?"
# +---------+-----------+
# | Words   |  Is Same  |
# +=========+===========+
# | के       |   True    |
# +---------+-----------+
# | इलाका     |   False   |
# +---------+-----------+
# | बताया     |   False   |
# +---------+-----------+
# | जारी      |   False   |
# +---------+-----------+
# | दुस्साहस   |   False   |
# +---------+-----------+
# | चीन      |   True    |
# +---------+-----------+
# | चिन      |   True    |
# +---------+-----------+
# | अपना     |   False   |
# +---------+-----------+
# | क्यों      |   False   |
# +---------+-----------+
# | पर      |   False   |
# +---------+-----------+
# | को       |   True    |
# +---------+-----------+
# | चुप      |   False   |
# +---------+-----------+
# | कर      |   False   |
# +---------+-----------+
# | China   |   False   |
# +---------+-----------+
# | ने       |   True    |
# +---------+-----------+
# | मैप      |   False   |
# +---------+-----------+
# | Modi    |   True    |
# +---------+-----------+
# | हैं       |   True    |
# +---------+-----------+
#
# Sentence: "लाल डायरी में BJP के मंत्रियों के नाम, देखते हैं Amit Shah क्या खुलासा करते हैं- Pawan Khera"
# +---------+-----------+
# | Words   |  Is Same  |
# +=========+===========+
# | Pawan   |   True    |
# +---------+-----------+
# | मंत्रियों    |   True    |
# +---------+-----------+
# | Khera   |   True    |
# +---------+-----------+
# | नाम      |   True    |
# +---------+-----------+
# | करते     |   True    |
# +---------+-----------+
# | देखते     |   False   |
# +---------+-----------+
# | BJP     |   True    |
# +---------+-----------+
# | लाल      |   True    |
# +---------+-----------+
# | डायरी     |   True    |
# +---------+-----------+
# | हैं       |   True    |
# +---------+-----------+
# | में       |   True    |
# +---------+-----------+
# | Shah    |   True    |
# +---------+-----------+
# | के       |   True    |
# +---------+-----------+
# | क्या      |   False   |
# +---------+-----------+
# | खुलासा     |   True    |
# +---------+-----------+
# | Amit    |   True    |
# +---------+-----------+
#
# Sentence: "4 दिन पहले Modi-Jinping की मुलाकात, अब चीन नक्शे में अरुणाचल, अक्‍साई चिन को अपना इलाका बता रहा है।"
# +---------+-----------+
# | Words   |  Is Same  |
# +=========+===========+
# | इलाका     |   True    |
# +---------+-----------+
# | की       |   True    |
# +---------+-----------+
# | अब      |   False   |
# +---------+-----------+
# | दिन      |   True    |
# +---------+-----------+
# | चीन      |   True    |
# +---------+-----------+
# | चिन      |   True    |
# +---------+-----------+
# | अक्‍साई     |   True    |
# +---------+-----------+
# | बता      |   True    |
# +---------+-----------+
# | है       |   True    |
# +---------+-----------+
# | अपना     |   False   |
# +---------+-----------+
# | अरुणाचल   |   True    |
# +---------+-----------+
# | में       |   True    |
# +---------+-----------+
# | पहले     |   False   |
# +---------+-----------+
# | को       |   True    |
# +---------+-----------+
# | रहा      |   True    |
# +---------+-----------+
# | नक्शे     |   True    |
# +---------+-----------+
# | 4       |   True    |
# +---------+-----------+
# | मुलाकात    |   True    |
# +---------+-----------+
#
# Sentence: "PM Modi से मुलाकात के 4 दिन बाद China ने अरुणाचल-अक्साई चिन को अपना इलाका बताया, भड़के Pawan Khera"
# +---------+-----------+
# | Words   |  Is Same  |
# +=========+===========+
# | Pawan   |   True    |
# +---------+-----------+
# | इलाका     |   True    |
# +---------+-----------+
# | Khera   |   True    |
# +---------+-----------+
# | भड़के     |   True    |
# +---------+-----------+
# | बताया     |   True    |
# +---------+-----------+
# | दिन      |   True    |
# +---------+-----------+
# | चिन      |   True    |
# +---------+-----------+
# | ने       |   False   |
# +---------+-----------+
# | अपना     |   False   |
# +---------+-----------+
# | बाद      |   False   |
# +---------+-----------+
# | से       |   False   |
# +---------+-----------+
# | Modi    |   True    |
# +---------+-----------+
# | को       |   True    |
# +---------+-----------+
# | के       |   True    |
# +---------+-----------+
# | China   |   True    |
# +---------+-----------+
# | PM      |   True    |
# +---------+-----------+
# | 4       |   False   |
# +---------+-----------+
# | मुलाकात    |   True    |
# +---------+-----------+
#
# Sentence: INDIA के साथ तरक्की के सफर पर चलेगा देश । INDIA Vs NDA | 2024 Election | Opposition Meeting Mumbai
# +------------+-----------+
# | Words      |  Is Same  |
# +============+===========+
# | के          |   True    |
# +------------+-----------+
# | Meeting    |   False   |
# +------------+-----------+
# | देश         |   True    |
# +------------+-----------+
# | चलेगा        |   True    |
# +------------+-----------+
# | Mumbai     |   True    |
# +------------+-----------+
# | सफर        |   True    |
# +------------+-----------+
# | Election   |   True    |
# +------------+-----------+
# | NDA        |   True    |
# +------------+-----------+
# | पर         |   True    |
# +------------+-----------+
# | Vs         |   False   |
# +------------+-----------+
# | तरक्की       |   False   |
# +------------+-----------+
# | 2024       |   True    |
# +------------+-----------+
# | Opposition |   True    |
# +------------+-----------+
# | INDIA      |   True    |
# +------------+-----------+
# | साथ         |   False   |
# +------------+-----------+
#
# Sentence: Patna और Bengaluru के बाद अब Mumbai में चक दे INDIA 🇮🇳 | Opposition Parties Meeting | Rahul Gandhi
# +------------+-----------+
# | Words      |  Is Same  |
# +============+===========+
# | और         |   True    |
# +------------+-----------+
# | Mumbai     |   True    |
# +------------+-----------+
# | 🇮🇳         |   True    |
# +------------+-----------+
# | अब         |   False   |
# +------------+-----------+
# | Meeting    |   True    |
# +------------+-----------+
# | Parties    |   True    |
# +------------+-----------+
# | Bengaluru  |   True    |
# +------------+-----------+
# | Rahul      |   True    |
# +------------+-----------+
# | चक         |   True    |
# +------------+-----------+
# | बाद         |   False   |
# +------------+-----------+
# | Gandhi     |   True    |
# +------------+-----------+
# | में          |   False   |
# +------------+-----------+
# | के          |   True    |
# +------------+-----------+
# | दे          |   False   |
# +------------+-----------+
# | Opposition |   True    |
# +------------+-----------+
# | INDIA      |   True    |
# +------------+-----------+
# | Patna      |   True    |
# +------------+-----------+
#
# Sentence: यात्रा' में बेबाक बोले INDIA के लोग। Bharat Jodo Yatra | Rahul Gandhi
# +---------+-----------+
# | Words   |  Is Same  |
# +=========+===========+
# | यात्रा     |   True    |
# +---------+-----------+
# | लोग      |   True    |
# +---------+-----------+
# | Bharat  |   True    |
# +---------+-----------+
# | Yatra   |   False   |
# +---------+-----------+
# | Rahul   |   True    |
# +---------+-----------+
# | Jodo    |   False   |
# +---------+-----------+
# | बोले      |   True    |
# +---------+-----------+
# | में       |   False   |
# +---------+-----------+
# | Gandhi  |   True    |
# +---------+-----------+
# | बेबाक     |   False   |
# +---------+-----------+
# | के       |   True    |
# +---------+-----------+
# | INDIA   |   True    |
# +---------+-----------+
#
# Sentence: "माता-पिता को राहत, कांग्रेस करा रही बेटियों की शादी। Congress | Rajasthan | Chhattisgarh"
# +--------------+-----------+
# | Words        |  Is Same  |
# +==============+===========+
# | की            |   True    |
# +--------------+-----------+
# | Congress     |   True    |
# +--------------+-----------+
# | बेटियों          |   True    |
# +--------------+-----------+
# | रही           |   True    |
# +--------------+-----------+
# | राहत          |   True    |
# +--------------+-----------+
# | करा           |   True    |
# +--------------+-----------+
# | को            |   True    |
# +--------------+-----------+
# | Rajasthan    |   True    |
# +--------------+-----------+
# | शादी           |   True    |
# +--------------+-----------+
# | Chhattisgarh |   True    |
# +--------------+-----------+
#
# Sentence: Modi-Adani की दोस्ती के चक्कर में देश बर्बाद हो रहा है... | Rahul Gandhi | Congress | BJP
# +----------+-----------+
# | Words    |  Is Same  |
# +==========+===========+
# | के        |   True    |
# +----------+-----------+
# | चक्कर     |   True    |
# +----------+-----------+
# | की        |   True    |
# +----------+-----------+
# | देश       |   True    |
# +----------+-----------+
# | Congress |   True    |
# +----------+-----------+
# | Adani    |   True    |
# +----------+-----------+
# | बर्बाद     |   True    |
# +----------+-----------+
# | दोस्ती      |   False   |
# +----------+-----------+
# | BJP      |   True    |
# +----------+-----------+
# | है        |   True    |
# +----------+-----------+
# | Gandhi   |   True    |
# +----------+-----------+
# | में        |   True    |
# +----------+-----------+
# | हो        |   True    |
# +----------+-----------+
# | रहा       |   True    |
# +----------+-----------+
# | Modi     |   True    |
# +----------+-----------+
#
# Sentence: "Mallikarjun Kharge ने कही बड़ी बात, अगर संविधान नहीं होता तो आज मैं... | Telangana | Congress"
# +-------------+-----------+
# | Words       |  Is Same  |
# +=============+===========+
# | Kharge      |   True    |
# +-------------+-----------+
# | बात          |   True    |
# +-------------+-----------+
# | संविधान        |   True    |
# +-------------+-----------+
# | Telangana   |   True    |
# +-------------+-----------+
# | Congress    |   True    |
# +-------------+-----------+
# | अगर         |   True    |
# +-------------+-----------+
# | नहीं          |   True    |
# +-------------+-----------+
# | तो           |   True    |
# +-------------+-----------+
# | होता          |   True    |
# +-------------+-----------+
# | आज          |   False   |
# +-------------+-----------+
# | कही          |   True    |
# +-------------+-----------+
# | Mallikarjun |   True    |
# +-------------+-----------+
# | बड़ी          |   True    |
# +-------------+-----------+
# | मैं           |   False   |
# +-------------+-----------+
#
# Sentence: "हम 2024 में BJP को हरा देंगे... जुड़ेगा भारत, जीतेगा INDIA | Rahul Gandhi | PM Modi"
# +---------+-----------+
# | Words   |  Is Same  |
# +=========+===========+
# | देंगे      |   True    |
# +---------+-----------+
# | Rahul   |   True    |
# +---------+-----------+
# | BJP     |   True    |
# +---------+-----------+
# | जुड़ेगा     |   False   |
# +---------+-----------+
# | जीतेगा     |   False   |
# +---------+-----------+
# | Gandhi  |   True    |
# +---------+-----------+
# | में       |   True    |
# +---------+-----------+
# | को       |   True    |
# +---------+-----------+
# | भारत     |   True    |
# +---------+-----------+
# | 2024    |   True    |
# +---------+-----------+
# | हरा      |   False   |
# +---------+-----------+
# | PM      |   True    |
# +---------+-----------+
# | हम      |   False   |
# +---------+-----------+
# | Modi    |   True    |
# +---------+-----------+
# | INDIA   |   True    |
# +---------+-----------+
#
# Sentence: मोदी सरकार 2-3 अरबपतियों की सरकार है- Rahul Gandhi | PM Modi
# +---------+-----------+
# | Words   |  Is Same  |
# +=========+===========+
# | मोदी      |   True    |
# +---------+-----------+
# | की       |   True    |
# +---------+-----------+
# | Rahul   |   True    |
# +---------+-----------+
# | है       |   False   |
# +---------+-----------+
# | Gandhi  |   True    |
# +---------+-----------+
# | PM      |   True    |
# +---------+-----------+
# | अरबपतियों  |   False   |
# +---------+-----------+
# | Modi    |   True    |
# +---------+-----------+
# | सरकार    |   True    |
# +---------+-----------+
#
# Sentence: "PM Modi के सामने झुकने से Nitin Gadkari का इंकार, 2024 से पहले BJP में बड़ी बगावत।"
# +---------+-----------+
# | Words   |  Is Same  |
# +=========+===========+
# | के       |   True    |
# +---------+-----------+
# | सामने     |   False   |
# +---------+-----------+
# | Gadkari |   True    |
# +---------+-----------+
# | बड़ी      |   False   |
# +---------+-----------+
# | BJP     |   True    |
# +---------+-----------+
# | 2024    |   True    |
# +---------+-----------+
# | बगावत    |   False   |
# +---------+-----------+
# | से       |   True    |
# +---------+-----------+
# | झुकने     |   True    |
# +---------+-----------+
# | पहले     |   False   |
# +---------+-----------+
# | में       |   True    |
# +---------+-----------+
# | Nitin   |   True    |
# +---------+-----------+
# | इंकार     |   True    |
# +---------+-----------+
# | का       |   False   |
# +---------+-----------+
# | PM      |   True    |
# +---------+-----------+
# | Modi    |   True    |
# +---------+-----------+
#
# Sentence: "ये है गुजरात मॉडल की असलियत, अब जनता झांसे में नहीं आएगी मोदी जी... | Gujarat Model | PM Modi"
# +---------+-----------+
# | Words   |  Is Same  |
# +=========+===========+
# | आएगी     |   True    |
# +---------+-----------+
# | जनता     |   True    |
# +---------+-----------+
# | की       |   True    |
# +---------+-----------+
# | अब      |   False   |
# +---------+-----------+
# | मोदी      |   True    |
# +---------+-----------+
# | जी       |   False   |
# +---------+-----------+
# | मॉडल     |   True    |
# +---------+-----------+
# | नहीं      |   True    |
# +---------+-----------+
# | गुजरात    |   True    |
# +---------+-----------+
# | Model   |   True    |
# +---------+-----------+
# | है       |   True    |
# +---------+-----------+
# | ये       |   False   |
# +---------+-----------+
# | झांसे      |   True    |
# +---------+-----------+
# | में       |   True    |
# +---------+-----------+
# | Gujarat |   True    |
# +---------+-----------+
# | असलियत   |   True    |
# +---------+-----------+
# | PM      |   True    |
# +---------+-----------+
# | Modi    |   True    |
# +---------+-----------+
#
# Sentence: Amit Shah को Mallikarjun Kharge ने दिया झन्नाटेदार जवाब। BJP नेताओं की बोलती बंद। Telangana Election
# +-------------+-----------+
# | Words       |  Is Same  |
# +=============+===========+
# | Kharge      |   True    |
# +-------------+-----------+
# | Telangana   |   True    |
# +-------------+-----------+
# | की           |   True    |
# +-------------+-----------+
# | झन्नाटेदार      |   False   |
# +-------------+-----------+
# | बोलती         |   False   |
# +-------------+-----------+
# | BJP         |   True    |
# +-------------+-----------+
# | बंद          |   False   |
# +-------------+-----------+
# | Election    |   False   |
# +-------------+-----------+
# | दिया          |   True    |
# +-------------+-----------+
# | जवाब         |   True    |
# +-------------+-----------+
# | Mallikarjun |   True    |
# +-------------+-----------+
# | Shah        |   True    |
# +-------------+-----------+
# | को           |   True    |
# +-------------+-----------+
# | ने           |   True    |
# +-------------+-----------+
# | नेताओं         |   True    |
# +-------------+-----------+
# | Amit        |   True    |
# +-------------+-----------+
#
# Sentence: तेलंगाना में सरकार बनते ही Congress 12 वादे पूरा करेगी- Mallikarjun Kharge | Telangana Election
# +-------------+-----------+
# | Words       |  Is Same  |
# +=============+===========+
# | 12          |   True    |
# +-------------+-----------+
# | पूरा          |   False   |
# +-------------+-----------+
# | ही           |   False   |
# +-------------+-----------+
# | Kharge      |   True    |
# +-------------+-----------+
# | Congress    |   True    |
# +-------------+-----------+
# | Telangana   |   True    |
# +-------------+-----------+
# | करेगी         |   True    |
# +-------------+-----------+
# | तेलंगाना        |   True    |
# +-------------+-----------+
# | Election    |   False   |
# +-------------+-----------+
# | में           |   True    |
# +-------------+-----------+
# | Mallikarjun |   True    |
# +-------------+-----------+
# | बनते         |   False   |
# +-------------+-----------+
# | वादे          |   True    |
# +-------------+-----------+
# | सरकार        |   True    |
# +-------------+-----------+

# %%
from collections import Counter


# Calculate Observed Agreement (P0)
# Initialize counters
true_count = 0
false_count = 0
total_count = 0

# Iterate through the dictionary
for key, value_dict in observed_agreement.items():
    for val in value_dict.values():
        if val:
            true_count += 1
        else:
            false_count += 1
        total_count += 1


print(f"True count: {true_count}")
print(f"False count: {false_count}")

P0 = true_count / total_count




# Calculate Expected Agreement (Pe)
# Flatten the word-labels from all sentences
labels_1 = [label for sentence in dataset1.values() for word, label in sentence.items()]
labels_2 = [label for sentence in dataset2.values() for word, label in sentence.items()]

# Count the occurrences of each label for both annotators
count_1 = Counter(labels_1)
count_2 = Counter(labels_2)
print(f"\nAnnotator 1 labels: {count_1}")
print(f"Annotator 2 labels: {count_2}")

# Total number of labels
total_labels_1 = len(labels_1)
total_labels_2 = len(labels_2)
print(f"\nAnnotator 1 total labels marked: {total_labels_1}")
print(f"Annotator 2 total labels marked: {total_labels_2}")

# Calculate Pe using the formula for expected agreement
Pe = 0
for label in count_1:
    prob_1 = count_1[label] / total_labels_1
    prob_2 = count_2.get(label, 0) / total_labels_2
    Pe += prob_1 * prob_2


# Step 3: Calculate Cohen's Kappa
kappa = (P0 - Pe) / (1 - Pe)

# Output results
print(f"\nObserved Agreement (P0): {P0:.4f}")
print(f"Expected Agreement (Pe): {Pe:.4f}")
print(f"Cohen's Kappa: {kappa:.4f}")
# Out:
# True count: 232
# False count: 76
#
# Annotator 1 labels: Counter({'PROPN': 114, 'NOUN': 72, 'ADP': 54, 'VERB': 38, 'ADJ': 13, 'ADV': 9, 'NUM': 8, 'CONJ': 4, 'PART': 2, 'PART_NEG': 2, 'DET': 1, 'PRON_WH': 1})
# Annotator 2 labels: Counter({'PROPN': 107, 'NOUN': 77, 'ADP': 49, 'VERB': 39, 'ADV': 20, 'ADJ': 15, 'NUM': 8, 'PRON': 7, 'CONJ': 5, 'X': 3, 'PART_NEG': 2, 'DET': 1})
#
# Annotator 1 total labels marked: 318
# Annotator 2 total labels marked: 333
#
# Observed Agreement (P0): 0.7532
# Expected Agreement (Pe): 0.2109
# Cohen's Kappa: 0.6873

# %% [markdown]
# # Fleiss Kappa for the CV Dataset Task
